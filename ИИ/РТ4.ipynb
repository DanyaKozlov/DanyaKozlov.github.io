# %% [markdown]
# ### Задание 1.1

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([0,1,2,3,4])
y = np.array([-2, 0.2, 1.8, 4, 6])
A = np.vstack([x, np.ones(len(x))]).T
A
m, c = np.linalg.lstsq(A,y, rcond = None)[0]

# %%
plt.plot(x,y, 'o', label = "Исходные данные", markersize=10)
plt.plot(x,m*x+c,'r',label="Линейная экстраполяция")
plt.legend()
plt.show()

# %%
from numpy import *
from numpy.random import *
delta = 2.0
x = linspace(-5,5,11)
y = x**2+delta*(rand(11)-0.5)
x += delta*(rand(11)-0.5)

# %%
m = vstack((x**2, x, ones(11))).T
s = np.linalg.lstsq(m,y, rcond = None)[0]
x_prec = linspace(-5,5,101)
plt.plot(x,y,"o")
plt.plot(x_prec, s[0]*x_prec**2+s[1]* x_prec+s[2], '-', lw=2)

plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
m = vstack((x**3, x**2, x, ones(11))).T
s = np.linalg.lstsq(m,y, rcond = None)[0]
x_prec = linspace(-5,5,101)
plt_plot(x,y,'D')
plt_plot(x_prec, s[0]*x_prec**3+s[1]*x_prec**2+s[2]*x_prec+s[3])
plt_grid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 6>()
#       4 s = np.linalg.lstsq(m,y, rcond = None)[0]
#       5 x_prec = linspace(-5,5,101)
# ----> 6 plt_plot(x,y,'D')
#       7 plt_plot(x_prec, s[0]*x_prec**3+s[1]*x_prec**2+s[2]*x_prec+s[3])
#       8 plt_grid
#
# NameError: name 'plt_plot' is not defined
